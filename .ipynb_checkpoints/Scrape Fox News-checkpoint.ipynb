# %%
from bs4 import BeautifulSoup
import requests
from splinter import Browser

executable_path = {'executable_path': './chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)


base_url = 'https://www.foxnews.com/search-results/search?q=trump&ss=fn&sort=latest&type=story&start='

fox_news_list = []

n=0
page = 0
i=0

for i in range(750):  

    url= base_url + str(page)
    browser.visit(url)
    
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    articles = soup.find_all('div',class_="search-article ng-scope")
    n=0

    for article in articles:
        try:
            date=articles[n].find('span').text
            headline=articles[n].find('a',class_="ng-binding").text
            summary = articles[n].find('p').text
            
            list_item = {"Date":date,"Headline":headline,"Summary":summary}
            fox_news_list.append(list_item)
            
            
        except (AttributeError):
            print('Missing Data')
        
        n=n+1
        
    page=page+10
    i=i+1
    print(i)
# Out:
# Missing Data
# 1
# Missing Data
# 2
# 3
# 4
# 5

# %%
import pandas as pd

fox_news = pd.DataFrame(fox_news_list).drop_duplicates("Headline")


fox_news.count()
# Out:
# Date        48
# Headline    48
# Summary     48
# dtype: int64

# %%
import requests
import json

from config2 import rkey

fox_news['Headline Positive'] = ""
fox_news['Headline Neutral'] = ""
fox_news['Headline Negative'] = ""

fox_news['Summary Positive'] = ""
fox_news['Summary Neutral'] = ""
fox_news['Summary Negative'] = ""

base_url = "https://japerk-text-processing.p.rapidapi.com/sentiment/"

headers={
    "X-RapidAPI-Key": rkey,
    "Content-Type": "application/x-www-form-urlencoded"
}

params={
    "language": "english"
    }

for index, row in fox_news.iterrows():
    
    params["text"]= row['Headline']   

    response = requests.post(base_url,headers=headers,data=params).json()
    
    try:
        print(f"{index}")
        fox_news.loc[index,'Headline Positive'] = response['probability']['pos']
        fox_news.loc[index,'Headline Neutral'] = response['probability']['neutral']
        fox_news.loc[index,'Headline Negative'] = response['probability']['neg']
    
    except(KeyError,IndexError):
        print("Missing Data")
        
    params["text"]= row['Summary']   

    response = requests.post(base_url,headers=headers,data=params).json()
    try:
        print(f"{index}")
        fox_news.loc[index,'Summary Positive'] = response['probability']['pos']
        fox_news.loc[index,'Summary Neutral'] = response['probability']['neutral']
        fox_news.loc[index,'Summary Negative'] = response['probability']['neg']
    
    except(KeyError,IndexError):
        print("Missing Data")

fox_news.head(20)
# Out:
#             Date                                           Headline  \
# 0   Mar 22, 2019  Mueller report: Here's a Dem's take -- If Trum...
# 1   Mar 22, 2019  Political reaction pours in after Mueller repo...
# 2   Mar 22, 2019  Trump to nominate economic analyst Stephen Moo...
# 3   Mar 22, 2019  Adam Schiff rejects reports that Mueller indic...
# 4   Mar 22, 2019  Kamala Harris calls for AG Barr to testify on ...
# 5   Mar 22, 2019  Celebs react to completed Robert Mueller repor...
# 6   Mar 22, 2019  Alan Dershowitz: Mueller just filed Russia rep...
# 7   Mar 22, 2019  Trump team ‘confident’ no collusion in Mueller...
# 8   Mar 22, 2019  MSBNC host Chuck Todd, panel herald 'remarkabl...
# 9   Mar 22, 2019  Mueller not recommending ‘any further indictme...
# 10  Mar 22, 2019  Top Dems want report, now submitted, made publ...
# 11  Mar 22, 2019  Paddlers can access Potomac when Trump visits ...
# 12  Mar 22, 2019  Attorney General Bill Barr's letter to lawmake...
# 13  Mar 22, 2019  Mueller submits long-awaited Russia probe repo...
# 14  Mar 22, 2019  California governor to declare statewide wildf...
# 15  Mar 22, 2019  Germany won't disclose Iranian attempts to obt...
# 16  Mar 22, 2019  Deroy Murdock: The war on MAGA hats (and Trump...
# 17  Mar 22, 2019  Puerto Rico mayor, Trump critic announces run ...
# 18  Mar 22, 2019  Sen. Mike Lee: Facebook, Google, others have b...
# 19  Mar 22, 2019  Gabbard pushes back on calls to nix Electoral ...
#
#                                               Summary Headline Positive  \
# 0   If President Trump truly has nothing to hide a...          0.753605
# 1   The submission of Special Counsel Robert Muell...          0.559888
# 2   President Donald Trump said Friday that he wil...          0.656324
# 3   Adam Schiff rejected reports that no more Muel...          0.293478
# 4   The Democratic presidential contenders are uni...           0.43343
# 5   Following news that Special Counsel Robert Mue...            0.6826
# 6   Hold your breath and stay tuned, America. And ...          0.697848
# 7   President Trump’s legal team projected confide...          0.616525
# 8   Moments after news broke Robert Mueller had su...          0.573356
# 9   Special Counsel Robert Mueller is not recommen...          0.308321
# 10  Special Counsel Robert Mueller submitted his l...          0.451067
# 11  Water sports enthusiasts will get more opportu...           0.40257
# 12  Attorney General Bill Barr has delivered a let...          0.426441
# 13  Special Counsel Robert Mueller has submitted t...          0.595802
# 14  California Governor Gavin Newsom plans to decl...          0.425681
# 15  Germany’s government refused to disclose the n...          0.415193
# 16  Three recent prosecutions suggest that Preside...          0.676577
# 17  The mayor of Puerto Rico's capital has announc...           0.58199
# 18  I’m worried that, in the rush to address our c...          0.332606
# 19  She may have been a top supporter of firebrand...          0.368816
#
#    Headline Neutral Headline Negative Summary Positive Summary Neutral  \
# 0          0.157803          0.246395         0.464779        0.789808
# 1          0.635098          0.440112         0.816369        0.814823
# 2          0.646259          0.343676         0.749947        0.848824
# 3          0.622041          0.706522         0.499045        0.721881
# 4          0.505699           0.56657         0.623423         0.84322
# 5          0.503411            0.3174         0.653008        0.853224
# 6          0.336773          0.302152         0.467824       0.0346407
# 7          0.252103          0.383475          0.50992        0.909077
# 8          0.436235          0.426644          0.30591        0.860005
# 9          0.445639          0.691679         0.614709        0.812265
# 10         0.722178          0.548933         0.603619        0.807023
# 11         0.920657           0.59743         0.500217        0.790614
# 12         0.803093          0.573559         0.537485        0.823108
# 13         0.780158          0.404198         0.580112        0.816816
# 14          0.78432          0.574319          0.22108        0.642709
# 15         0.809213          0.584807         0.582339        0.845741
# 16         0.463645          0.323423         0.718162         0.61705
# 17         0.785656           0.41801         0.513986        0.978486
# 18         0.920404          0.667394         0.274514        0.621017
# 19          0.83873          0.631184         0.388995        0.781832
#
#    Summary Negative
# 0          0.535221
# 1          0.183631
# 2          0.250053
# 3          0.500955
# 4          0.376577
# 5          0.346992
# 6          0.532176
# 7           0.49008
# 8           0.69409
# 9          0.385291
# 10         0.396381
# 11         0.499783
# 12         0.462515
# 13         0.419888
# 14          0.77892
# 15         0.417661
# 16         0.281838
# 17         0.486014
# 18         0.725486
# 19         0.611005

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, MetaData
import pymysql

from config2 import sp


location = f"postgresql://postgres:{sp}@localhost:5432/ETL_Project"

engine = create_engine(location)

metadata = MetaData()
metadata.reflect(engine)

Base=automap_base(metadata=metadata)

Base.prepare()

news = Base.classes.fox_news

session = Session(engine)

for index, row in fox_news.iterrows():
    
    session.add(news(date=row['Date'],headline=row['Headline'],summary=row['Summary'], pos_head=row['Headline Positive'],neg_head=row['Headline Negative'],neut_head=row['Headline Neutral'],pos_sum=row['Summary Positive'], neg_sum=row['Summary Negative'],neut_sum=row['Summary Neutral']))
    session.commit()
